# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data  = pd.read_csv("[Dataset]_Module11_Train_(Employee).csv")

# %%
data.head(10)
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
# 5    EID_2278      M  54.0                3             Married      Lebanon
# 6   EID_18588      F  21.0                4             Married  Springfield
# 7    EID_1235      F   NaN                3             Married  Springfield
# 8   EID_10197      M  40.0                4              Single  Springfield
# 9   EID_21262      M  45.0                3             Married      Lebanon
#
#                         Unit Decision_skill_possess  Time_of_service  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                7000 non-null   object
#  1   Gender                     7000 non-null   object
#  2   Age                        6588 non-null   float64
#  3   Education_Level            7000 non-null   int64
#  4   Relationship_Status        7000 non-null   object
#  5   Hometown                   7000 non-null   object
#  6   Unit                       7000 non-null   object
#  7   Decision_skill_possess     7000 non-null   object
#  8   Time_of_service            6856 non-null   float64
#  9   Time_since_promotion       7000 non-null   int64
#  10  growth_rate                7000 non-null   int64
#  11  Travel_Rate                7000 non-null   int64
#  12  Post_Level                 7000 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6',
#        'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_23371      F  42.0                4             Married
# 1      EID_18000      M  24.0                3              Single
# 2       EID_3891      F  58.0                3             Married
# 3      EID_17492      F  26.0                3              Single
# 4      EID_22534      F  31.0                1             Married
# ...          ...    ...   ...              ...                 ...
# 6995   EID_16328      F  23.0                5             Married
# 6996    EID_8387      F  44.0                1             Married
# 6997    EID_8077      F  49.0                3              Single
# 6998   EID_19597      F  47.0                3             Married
# 6999    EID_1640      F  58.0                3             Married
#
#          Hometown                       Unit Decision_skill_possess  \
# ...

# %%
data.isna().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          412
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              144
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      9
# Compensation_and_Benefits      0
# Work_Life_balance             11
# VAR1                           0
# VAR2                         577
# VAR3                           0
# VAR4                         656
# VAR5                           0
# VAR6                           0
# VAR7                           0
# Attrition_rate                 0
# dtype: int64

# %%
# data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data.isna().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          412
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              144
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      9
# Compensation_and_Benefits      0
# Work_Life_balance             11
# VAR1                           0
# VAR2                         577
# VAR3                           0
# VAR4                         656
# VAR5                           0
# VAR6                           0
# VAR7                           0
# Attrition_rate                 0
# dtype: int64

# %%
data.dtypes
# Out:
# Employee_ID                   object
# Gender                        object
# Age                          float64
# Education_Level                int64
# Relationship_Status           object
# Hometown                      object
# Unit                          object
# Decision_skill_possess        object
# Time_of_service              float64
# Time_since_promotion           int64
# growth_rate                    int64
# Travel_Rate                    int64
# Post_Level                     int64
# Pay_Scale                    float64
# Compensation_and_Benefits     object
# Work_Life_balance            float64
# VAR1                           int64
# VAR2                         float64
# VAR3                         float64
# VAR4                         float64
# VAR5                           int64
# VAR6                           int64
# VAR7                           int64
# Attrition_rate               float64
# dtype: object

# %%
missing_values = ['Age','Time_of_service','Work_Life_balance','Pay_Scale','VAR2','VAR4']

# %%
for col in missing_values:
    data[col] = data[col].fillna(data[col].mean())

# %%
data.isna().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Age                          0
# Education_Level              0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR1                         0
# VAR2                         0
# VAR3                         0
# VAR4                         0
# VAR5                         0
# VAR6                         0
# VAR7                         0
# Attrition_rate               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6',
#        'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
new_data = data.select_dtypes(["int","float64"])

# %%
cor = new_data.corr()
plt.figure(figsize = (20,10))
sns.heatmap(cor , annot = True, cmap = plt.cm.Accent)
plt.tight_layout()
plt.show()
plt.savefig("main_correlation.png")

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6',
#        'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
x = data[['VAR7','VAR6','VAR5','VAR3','VAR1','Time_since_promotion', 'growth_rate', 'Travel_Rate','Time_of_service','Post_Level','Education_Level']]

# %%
y = data[["Attrition_rate"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=123,shuffle=True)
print(f"x training {x_train.shape}")
print(f"y training {y_train.shape}")
print(f"x testing {x_test.shape}")
print(f"y testing {y_test.shape}")
# Out:
# x training (5600, 11)
# y training (5600, 1)
# x testing (1400, 11)
# y testing (1400, 1)

# %%
from sklearn.linear_model import LinearRegression
model_lr=LinearRegression()
model_lr
# Out:
# LinearRegression()

# %%
model_lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model_lr.predict(x_test)
# Out:
# array([[0.20238057],
#        [0.20076846],
#        [0.19070954],
#        ...,
#        [0.19255234],
#        [0.19356688],
#        [0.1949135 ]])

# %%
y_pred=model_lr.predict(x_test)
y_pred
# Out:
# array([[0.20238057],
#        [0.20076846],
#        [0.19070954],
#        ...,
#        [0.19255234],
#        [0.19356688],
#        [0.1949135 ]])

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
mse=mean_squared_error(y_test,y_pred)
print(f"mean square error is {mse}")
rmse=sqrt(mse)
print(f"Root  mean squared error is {rmse}")
# Out:
# mean square error is 0.036804181101907855
# Root  mean squared error is 0.1918441583731646

# %%
from sklearn.metrics import r2_score

# %%
r_squared=r2_score(y_test,y_pred)
print(f"R SQUARE IS {r_squared}")
# Out:
# R SQUARE IS -0.00686900636392207

# %%
print(f"Constant Value is {model_lr.intercept_}")
# Out:
# Constant Value is [0.21407848]

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

# %%
select_models=[LinearRegression(), 
              DecisionTreeRegressor(max_depth=None,min_samples_leaf=2,min_samples_split=5), 
              RandomForestRegressor(max_depth=None,min_samples_leaf=2,min_samples_split=5,n_estimators=100)]

# %%
my_rmse=[]
my_r_square=[]
adj_r2_square_value=[]
for model in select_models:
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    rmse=sqrt(mean_squared_error(y_pred,y_test))
    my_rmse.append(rmse)
    r_sq=r2_score(y_pred,y_test)
    my_r_square.append(r_sq)
    print(f"RMSE value {my_rmse} and R Sqaured value {my_r_square} of model {model}")
# Out:
# RMSE value [0.1918441583731646] and R Sqaured value [-391.98830200101975] of model LinearRegression()
# RMSE value [0.1918441583731646, 0.25026965106856675] and R Sqaured value [-391.98830200101975, -1.3206872718303226] of model DecisionTreeRegressor(min_samples_leaf=2, min_samples_split=5)
# RMSE value [0.1918441583731646, 0.25026965106856675, 0.19482582113379499] and R Sqaured value [-391.98830200101975, -1.3206872718303226, -21.903903796338195] of model RandomForestRegressor(min_samples_leaf=2, min_samples_split=5)

# %%
result=[my_rmse ,my_r_square]
result
# Out:
# [[0.1918441583731646, 0.25026965106856675, 0.19482582113379499],
#  [-391.98830200101975, -1.3206872718303226, -21.903903796338195]]

# %%
a=pd.DataFrame(data=result,columns=(["LinearRegression","DecisionTree","RandomForest"]),index=["my_rmse","my_r_square"])
a
# Out:
#              LinearRegression  DecisionTree  RandomForest
# my_rmse              0.191844      0.250270      0.194826
# my_r_square       -391.988302     -1.320687    -21.903904

# %%
import pickle
pickle.dump(model_lr,open("employeeattrition.pkl","wb"))
